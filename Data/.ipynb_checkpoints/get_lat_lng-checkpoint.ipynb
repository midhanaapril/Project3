# %%
import pandas as pd
import requests
import numpy as nan
import math
import pprint

# %%
df= pd.read_csv('beer_association_scrape.csv')
df
# Out:
#                                  company_name company_type    company_phone  \
# 0                                  52 Brewing     Planning  no phone number
# 1                          6S Brewing Company      Taproom   (678) 597-8335
# 2                       Abide Brewing Company        Micro   (678) 972-6747
# 3                    Akademia Brewing Company      Brewpub   (706) 461-3208
# 4                           Amici At Trillith      Brewpub   (678) 892-5858
# ..                                        ...          ...              ...
# 169                  Whistle Top Brew Company      Taproom   (706) 776-9556
# 170  Wild Heaven - West End Brewery & Gardens      Brewpub   (404) 997-8589
# 171                          Wild Heaven Beer        Micro   (404) 997-8589
# 172                 Wild Leap Brewing Company        Micro   (706) 298-6400
# 173                             Yes Face Beer     Contract   (404) 213-3867
#
# ...

# %%
df2 = df[df['street_address'].notna()]
df2
# Out:
#                                  company_name company_type   company_phone  \
# 1                          6S Brewing Company      Taproom  (678) 597-8335
# 2                       Abide Brewing Company        Micro  (678) 972-6747
# 3                    Akademia Brewing Company      Brewpub  (706) 461-3208
# 4                           Amici At Trillith      Brewpub  (678) 892-5858
# 5                               Amici Madison      Brewpub  (706) 342-0000
# ..                                        ...          ...             ...
# 168                   Variant Brewing Company      Taproom  (770) 598-5002
# 169                  Whistle Top Brew Company      Taproom  (706) 776-9556
# 170  Wild Heaven - West End Brewery & Gardens      Brewpub  (404) 997-8589
# 171                          Wild Heaven Beer        Micro  (404) 997-8589
# 172                 Wild Leap Brewing Company        Micro  (706) 298-6400
#
# ...

# %%
addresses = df2['street_address'] + " " + df2['city'] + " " + df2['state']
address = addresses.tolist()
address
# Out:
# ['3111 Main Street Duluth,  GA',
#  '110 Werz Industrial Blvd Ste 130 Newnan,  GA',
#  '150 Crane Dr Athens,  GA',
#  '355 Trilith Parkway STE 110 Fayetteville,  GA',
#  '174 W Washington St Madison,  GA',
#  '110 Technology Parkway Peachtree Corners,  GA',
#  '341 E Main St Blue Ridge,  GA',
#  '100 Busch Dr NE Cartersville,  GA',
#  '3361 Dogwood Dr Hapeville,  GA',
#  '108 Park Ave Athens,  GA',
#  '2323 Defoor Hills Rd NW Atlanta,  GA',
#  '240 Lee St. Fayetteville,  GA',
#  '3472 Bethany Church Rd Lincolnton,  GA',
#  '1226 Ocean Blvd #1  St. Simons Island,  GA',
#  '700 Lincoln St. LaGrange,  GA',
#  '1036 White St SW Atlanta,  GA',
#  '537 Edgewood Ave Atlanta,  GA',
#  '4098 Lawrenceville Hwy Lilburn,  GA',
#  '2316 Main St STE K Tucker,  GA',
#  '907 Dilworth St Saint Marys,  GA',
#  '9859 Davis St Braselton,  GA',
#  '76 seven hills BLVD Dallas,  GA',
#  '2260 Moon Station Ct NW Ste 210 Kennesaw,  GA',
#  '1660 Dekalb Ave Atlanta,  GA',
#  '1041 Broadway Columbus,  GA',
# ...

# %%
API_KEY = 'AIzaSyB9Y5b2UyHiMSj0e3U8jJiWNZJxE5u5ndQ'
base_url = 'https://maps.googleapis.com/maps/api/geocode/json?'
lat = []
lng = []
confirmed = []
for x in address:
    query = base_url + x
    params = {
    'key': API_KEY,
    'address': x
    } 
    
    
    response = requests.get(base_url, params=params).json()
    
    geometry = response['results'][0]['geometry']
    lat.append(geometry['location']['lat'])
    lng.append(geometry['location']['lng'])
    confirmed.append(x)
    print(f"{x} found! Appending stats")
# Out:
# 3111 Main Street Duluth,  GA found! Appending stats
# 110 Werz Industrial Blvd Ste 130 Newnan,  GA found! Appending stats
# 150 Crane Dr Athens,  GA found! Appending stats
# 355 Trilith Parkway STE 110 Fayetteville,  GA found! Appending stats
# 174 W Washington St Madison,  GA found! Appending stats
# 110 Technology Parkway Peachtree Corners,  GA found! Appending stats
# 341 E Main St Blue Ridge,  GA found! Appending stats
# 100 Busch Dr NE Cartersville,  GA found! Appending stats
# 3361 Dogwood Dr Hapeville,  GA found! Appending stats
# 108 Park Ave Athens,  GA found! Appending stats
# 2323 Defoor Hills Rd NW Atlanta,  GA found! Appending stats
# 240 Lee St. Fayetteville,  GA found! Appending stats
# 3472 Bethany Church Rd Lincolnton,  GA found! Appending stats
# 1226 Ocean Blvd #1  St. Simons Island,  GA found! Appending stats
# 700 Lincoln St. LaGrange,  GA found! Appending stats
# 1036 White St SW Atlanta,  GA found! Appending stats
# ...

# %%
print(len(lat))
print(len(lng))
print(len(confirmed))
# Out:
# 161
# 161
# 161

# %%
newDF = pd.DataFrame({
    'address': confirmed,
    'latitude': lat,
    'longitude': lng
})
newDF
# Out:
#                                            address   latitude  longitude
# 0                     3111 Main Street Duluth,  GA  34.002944 -84.145058
# 1     110 Werz Industrial Blvd Ste 130 Newnan,  GA  33.400220 -84.763793
# 2                         150 Crane Dr Athens,  GA  33.942272 -83.470440
# 3    355 Trilith Parkway STE 110 Fayetteville,  GA  33.469082 -84.507183
# 4                 174 W Washington St Madison,  GA  33.596182 -83.469315
# ..                                             ...        ...        ...
# 156                    66 Norcross St Roswell,  GA  34.025787 -84.359093
# 157                    248 N Main St Cornelia,  GA  34.513363 -83.527738
# 158                  1010 White St SW Atlanta,  GA  33.730182 -84.419203
# 159                     135B Maple St Decatur,  GA  33.776472 -84.276167
# 160                      308 Main St Lagrange,  GA  33.034826 -85.031385
#
# [161 rows x 3 columns]

# %%
df2.to_csv('beer_association_scrape_clean.csv', index=False)
newDF.to_csv('beer_association_lat_lng.csv', index=False)
